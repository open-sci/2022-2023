# %% [markdown]
# <h1 style="text-align:center; text-decoration:underline"><span style="color: #1AA7EC">S</span>ebastiano's <span style="color: #1AA7EC">N</span>otebook</h1>
# <br>
# <br>
# <p style="font-size: 14.5px">This is a Jupyter Notebook to keep track of the thoughts and progresses about the <b>Open Science</b> project (DHDK - a.y. 2022-2023). The research question to be tackled is the following one:</p>
# <div style="padding-left: 25px; padding-right: 43px; padding-top: 8px; display:block"><p style="text-align:justify; font-size:14px"><em>"What is the coverage of publications in Social Science and Humanities (SSH) journals (according to ERIH-PLUS) included in OpenCitations Meta? What are the disciplines that have more publications? What are countries providing the largest number of publications and journals? How many of the SSH journals are available in Open Access according to the data in DOAJ?"</em></p></div>
# <br>
# <div style="display:block; background-color: #e9fce9; border-radius: 3px; border: 1pt solid #a6f1a6; padding: 8px 10px; width: 30%; margin-left:2%; margin-top: 12px">
#     <div style="display:inline-block; width: 50%">
#         <p style="font-size:15px; padding-left: 15px, padding-top: 10px"><b>Go to date:</b></p>
#         <ul style="font-size:14px">
#             <li><a href="#27/03/2023" style="color:#333; font-style: italic;">27/03/2023</a></li>
#             <li><a href="#28/03/2023" style="color:#333; font-style: italic;">28/03/2023</a></li>
#             <li><a href="#31/03/2023" style="color:#333; font-style: italic;">31/03/2023</a></li>
#             <li><a href="#04/04/2023" style="color:#333; font-style: italic;">04/04/2023</a></li>
#             <li><a href="#11/04/2023" style="color:#333; font-style: italic;">11/04/2023</a></li>
#             <li><a href="#15/04/2023" style="color:#333; font-style: italic;">15/04/2023</a></li>
#             <li><a href="#26/04/2023" style="color:#333; font-style: italic;">26/04/2023</a></li>
#             <li><a href="#02/05/2023" style="color:#333; font-style: italic;">02/05/2023</a></li>
#             <li><a href="#08/05/2023" style="color:#333; font-style: italic;">08/05/2023</a></li>
#             <li><a href="#09/05/2023" style="color:#333; font-style: italic;">09/05/2023</a></li>
#             <li><a href="#18/05/2023" style="color:#333; font-style: italic;">18/05/2023</a></li>
#         </ul>
#     </div>
#     <img src="https://www.transparentpng.com/thumb/calendar/green-calendar-vector-icon-png-20.png" alt="green calendar vector icon png @transparentpng.com" style="display:inline-block; width:45%; margin-top: -80px">
# </div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="27/03/2023" style="text-decoration:underline">27/03/2023</h3>
# <p style="font-size: 14.5px">First of all, let's try to subdivide our research questions into smaller units:</p>
# <table style="display:block; float:left; font-size: 14px; margin-bottom: 15px">
#     <tr>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Question</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Resources to be used</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Possible solution</th>
#       </tr>
#       <tr>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Coverage of publications in SSH journals included in OpenCitations Met</td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><a href="https://kanalregister.hkdir.no/publiseringskanaler/erihplus/">ERIH-PLUS</a>, <a href="http://opencitations.net/meta">OpenCitations Meta</a></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Extract publications in SSH journals; use the dois to find the intersection of the two datasets.</td>
#       </tr>
#       <tr>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Disciplines and countries providing more publications/journals</td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><a href="https://kanalregister.hkdir.no/publiseringskanaler/erihplus/">ERIH-PLUS</a></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Pandas DataFrame to sql; Sql query</td>
#       </tr>
#       <tr>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">How many SSH journals are available in Open Access</td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><a href="https://kanalregister.hkdir.no/publiseringskanaler/erihplus/">ERIH-PLUS</a>, <a href="https://doaj.org/">DOAJ</a></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Intersection of journals (maybe using ISSN)</td>
#       </tr>
# </table>
# <p style="font-size:14.5px; text-align: justify">The analysis of the research question allows understanding what is the <b>purpose</b> of the project. Our goal is to investigate the <b>openness</b> of <b>SSH publications</b> and to analyse how different disciplines and countries approach Open Science. At the same time, a primary is played by <b>citations</b>, as they represent a measure of the diffusion and sharing of a publication.</p>
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: analysis of the reaserch question; possible draft of our project's abstract published in <a href="https://github.com/open-sci/2022-2023/commit/bcfc173e2d3e615ec3c32985fb68346a1eb201fd">Github</a></p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="28/03/2023" style="text-decoration:underline">28/03/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">Let's start working on our datasets. The first one I would like to analyze is ERIH-PLUS. This is an academic journal index: the data is available in the form of a <code>.csv</code> file at the following <a href="https://kanalregister.hkdir.no/publiseringskanaler/erihplus/periodical/listApproved">link</a>. Let's try to upload this file using Pandas.

# %%
import pandas as pd

erih_plus = pd.read_csv("2023-03-27 ERIH PLUS.csv", sep=";")
erih_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11072 entries, 0 to 11071
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Journal ID              11072 non-null  int64
#  1   Print ISSN              8747 non-null   object
#  2   Online ISSN             9515 non-null   object
#  3   Original Title          11072 non-null  object
#  4   International Title     11072 non-null  object
#  5   Country of Publication  10952 non-null  object
#  6   ERIH PLUS Disciplines   11072 non-null  object
#  7   OECD Classifications    11072 non-null  object
#  8   [Last Updated]          11072 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 778.6+ KB

# %%
erih_plus.head()
# Out:
#    Journal ID Print ISSN Online ISSN  \
# 0      486254  1989-3477         NaN
# 1      488561        NaN   2341-0515
# 2      504135        NaN   2068-3472
# 3      495209  2250-4591   2346-9986
# 4      488332        NaN   0719-5737
#
#                                       Original Title  \
# 0                 @tic.revista d'innovació educativa
# 1  [i2] Investigación e Innovación en Arquitectur...
# 2                                    [Inter]sections
# 3             +E: Revista de Extensión Universitaria
# 4                                             100-Cs
#
#                                  International Title Country of Publication  \
# 0                 @tic.revista d'innovació educativa                  Spain
# 1  [i2] Investigación e Innovación en Arquitectur...                  Spain
# 2                                    [Inter]sections                Romania
# 3             +E: Revista de Extensión Universitaria              Argentina
# 4                                             100-Cs                  Chile
#
#                                ERIH PLUS Disciplines  \
# 0  Interdisciplinary research in the Social Scien...
# 1  Art and Art History, Cultural Studies, Human G...
# 2  Gender Studies, Cultural Studies, Literature, ...
# 3  Interdisciplinary research in the Humanities, ...
# 4  Interdisciplinary research in the Social Sciences
#
#                                 OECD Classifications       [Last Updated]
# 0        Educational Sciences; Other Social Sciences  2015-06-25 13:48:26
# 1  Arts (Arts, History of Arts, Performing Arts, ...  2016-04-18 17:34:55
# 2  Languages and Literature; Other Humanities; So...  2022-10-18 08:40:28
# 3            Other Humanities; Other Social Sciences  2023-02-02 17:14:12
# 4                              Other Social Sciences  2018-04-26 16:33:26

# %% [markdown]
# <p style="font-size: 14.5px">Let's try to check the content of the a cell in the <code>ERIH PLUS Disciplines</code> column</p>

# %%
erih_plus.at[1,"ERIH PLUS Disciplines"]
# Out:
# 'Art and Art History, Cultural Studies, Human Geography and Urban Studies, Interdisciplinary research in the Humanities, Interdisciplinary research in the Social Sciences, Pedagogical & Educational Research, Science and Technology Studies'

# %% [markdown]
# <p style="font-size: 14.5; text-align: justify">As we can see, <b>multiple disciplines</b> are included in the same journal: thus, we need to check for single publications in order to get some more detailed information. To get this information we could try to exploit this <a href="https://erih.dimensions.ai/discover/publication">link</a>. Here we can find all the publications included in the ERIH-PLUS database's journals. However, the system seems to allows users to export a maximum of 500 publications per time, meaning that it's almost impossible to retrieve all the information about the 10,769,086 currently included in the system. Nevertheless, let's try to analyze one of these exported files:</p>

# %%
erih_plus_500_publications = pd.read_csv("ERIH-PLUS 500.csv")
erih_plus_500_publications.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              500 non-null    int64
#  1   Publication ID                    500 non-null    object
#  2   DOI                               500 non-null    object
#  3   PMID                              462 non-null    float64
#  4   PMCID                             343 non-null    object
#  5   Title                             500 non-null    object
#  6   Abstract                          500 non-null    object
#  7   Acknowledgements                  309 non-null    object
#  8   Funding                           267 non-null    object
#  9   Source title                      500 non-null    object
#  10  Anthology title                   0 non-null      float64
#  11  MeSH terms                        233 non-null    object
#  12  Publication Date                  500 non-null    object
#  13  PubYear                           500 non-null    int64
#  14  Publication Date (online)         500 non-null    object
#  15  Publication Date (print)          181 non-null    object
#  16  Volume                            385 non-null    object
#  17  Issue                             371 non-null    object
#  18  Pagination                        461 non-null    object
#  19  Open Access                       500 non-null    object
#  20  Publication Type                  500 non-null    object
#  21  Authors                           500 non-null    object
#  22  Authors (Raw Affiliation)         500 non-null    object
#  23  Corresponding Authors             369 non-null    object
#  24  Authors Affiliations              500 non-null    object
#  25  Times cited                       500 non-null    int64
#  26  Recent citations                  500 non-null    int64
#  27  RCR                               0 non-null      float64
#  28  FCR                               0 non-null      float64
#  29  Source Linkout                    500 non-null    object
#  30  ERIH PLUS by Dimensions URL       500 non-null    object
#  31  Fields of Research (ANZSRC 2020)  500 non-null    object
#  32  Sustainable Development Goals     188 non-null    object
# dtypes: float64(4), int64(4), object(25)
# memory usage: 129.0+ KB

# %%
erih_plus_500_publications.head()
# Out:
#    Rank  Publication ID                           DOI        PMID  \
# 0   500  pub.1155098456          10.1162/jocn_a_01972  36735619.0
# 1   500  pub.1154380038          10.1162/jocn_a_01959  36626349.0
# 2   500  pub.1147283528           10.1037/pspp0000420  35446080.0
# 3   500  pub.1153677667            10.1037/bne0000544  36521141.0
# 4   500  pub.1156401252  10.1371/journal.pone.0283259  36947531.0
#
#          PMCID                                              Title  \
# 0  PMC10024573  Time Courses of Attended and Ignored Object Re...
# 1          NaN  Cochlear Theta Activity Oscillates in Phase Op...
# 2          NaN  Trait-Specificity Versus Global Positivity: A ...
# 3          NaN  Pair housing does not alter incubation of crav...
# 4  PMC10032514  Human scent signature on cartridge case surviv...
#
#                                             Abstract Acknowledgements  \
# 0  Selective attention prioritizes information th...              NaN
# 1  It is widely established that sensory percepti...              NaN
# 2  For decades, a recurring question in person pe...              NaN
# 3  Evidence suggests that single housing in rats ...              NaN
# 4  This paper focuses on a chemical analysis of h...              NaN
#
#                                              Funding  \
# 0  Sean Noah, National Eye Institute (https://dx....
# 1  DOC Fellowship Programme of the Austrian Acade...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Source title  ...  \
# 0             Journal of Cognitive Neuroscience  ...
# 1             Journal of Cognitive Neuroscience  ...
# 2  Journal of Personality and Social Psychology  ...
# 3                       Behavioral Neuroscience  ...
# 4                                      PLOS ONE  ...
#
#                                Corresponding Authors  \
# 0                                                NaN
# 1                                                NaN
# 2  Thielmann, Isabel (; University of Münster; Un...
# 3                                                NaN
# 4                                                NaN
#
#                                 Authors Affiliations Times cited  \
# 0  Noah, Sean (University of California, Davis; U...           0
# 1  Köhler, Moritz Herbert Albrecht (University of...           0
# 2  Thielmann, Isabel (University of Münster; Univ...           2
# 3             Nett, Kelle E (); LaLumiere, Ryan T ()           0
# 4  Ladislavová, Nikola (University of Chemistry a...           0
#
#    Recent citations RCR FCR  \
# 0                 0 NaN NaN
# 1                 0 NaN NaN
# 2                 2 NaN NaN
# 3                 0 NaN NaN
# 4                 0 NaN NaN
#
#                                       Source Linkout  \
# 0                https://psyarxiv.com/2aj3n/download
# 1          https://doi.org/10.1101/2022.02.21.481289
# 2                https://psyarxiv.com/z78na/download
# 3          https://doi.org/10.1101/2022.07.28.501777
# 4  https://journals.plos.org/plosone/article/file...
#
#                          ERIH PLUS by Dimensions URL  \
# 0  https://erih.dimensions.ai/details/publication...
# 1  https://erih.dimensions.ai/details/publication...
# 2  https://erih.dimensions.ai/details/publication...
# 3  https://erih.dimensions.ai/details/publication...
# 4  https://erih.dimensions.ai/details/publication...
#
#                     Fields of Research (ANZSRC 2020)  \
# 0  52 Psychology; 5202 Biological Psychology; 520...
# 1  32 Biomedical and Clinical Sciences; 3202 Clin...
# 2  52 Psychology; 5201 Applied and Developmental ...
# 3  32 Biomedical and Clinical Sciences; 3214 Phar...
# 4    34 Chemical Sciences; 3401 Analytical Chemistry
#
#   Sustainable Development Goals
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3  3 Good Health and Well Being
# 4                           NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# <p style="font-size:14.5px">As we can see, the third colum is named <code>DOI</code>, so this DataFrame contains some specifical information we might be interested in.</p>

# %%
erih_plus_500_publications.at[0, "Fields of Research (ANZSRC 2020)"]
# Out:
# '52 Psychology; 5202 Biological Psychology; 5204 Cognitive and Computational Psychology'

# %% [markdown]
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: analysis of the ERIH-PLUS dump file and search by DOI; abstract updated in <a href="https://github.com/open-sci/2022-2023/commit/f08398b6ad90fef436f10be3c6940bfc55d86fa8">Github</a></p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="31/03/2023" style="text-decoration:underline">31/03/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">First task of the day: create a personal ORCID (available at this <a href="https://orcid.org/0009-0007-7813-0939">link</a>). The next step will be about creating the team's <b>Data Management Plan</b> for the project. Let's try to collect some ideas before the next meeting: the first source is the following article, <em>Ten Simple Rules for Creating a Good Data Management Plan</em> by William K. Michener (<a href="https://doi.org/10.1371/journal.pcbi.1004525">doi.org/10.1371/journal.pcbi.1004525</a>).</p>
# <div style="padding-left: 25px; padding-right: 43px; padding-top: 8px; display:block"><p style="text-align:justify; font-size:14px"><em>"A data management plan (DMP) is a document that describes how you will treat your data during a project and what happens with the data after the project ends."</em></p></div>
# <p style="text-align:justify; font-size: 14.5px">The author identifies 10 main rules for producing a good DMP: although they are all crucial, which of them could be the most useful ones for our project?</p>
# <ul>
#     <li><b>Rule 2: Identify the Data to Be Collected</b> - There are some essential characteristics one should understand while working on some data: <em>types</em>, <em>sources</em> (in our case, the sources can be defined by analyzing the research question), <em>volume</em> (i.e., volume of data and number of files), <em>data and format files</em> (<code>.csv</code> files are expected to represent the major format of our data).</li>
#     <li><b>Rules 3, 4: How the Data will be Organized and Documented</b> - At this stage, one should design a possible way to organize data. At the same time data should be documented (through metadata) to avoid meaninglessness.</li>
#     <li><b>Rule 6: Present a Sound Data Storage and Preservation Strategy</b> - This rule deals with the preservation of our data. In our case, <a href="https://zenodo.org/">Zenodo</a> will probably our main ally. However, there are three main questions we should answer:
#         <em>
#             <ol>
#                 <li>How long will the data be accessible?</li>
#                 <li>How will data be stored and protected over the duration of the project?</li>
#                 <li> How will data be preserved and made available for future use?</li>
#             </ol>
#         </em>
#     </li>
#     <li><b>Rule 9: Assign Roles and Responsibilities</b> - It is important to define who will tackle specific parts of the project. However, also contributions by nonproject staff should be recorded in the DMP.</li>
# </ul>
# <p style="text-align:justify; font-size: 14.5px">Note that the DMP will be updated several times:</p>
# <div style="padding-left: 25px; padding-right: 43px; padding-top: 8px; display:block"><p style="text-align:justify; font-size:14px"><em>"Treat your DMP as a living document and revisit it frequently."</em></p></div>
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: creation of a personal ORCID; introductory <a href="https://doi.org/10.1371/journal.pcbi.1004525">reading</a> on how to prepare a DMP</p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="04/04/2023" style="text-decoration:underline">04/04/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">During the last meeting (02 April) me and my team started to create a Data Management Plan on <a href="https://argos.openaire.eu/splash/">Argos OpenAIRE</a>. We wrote together the metadata of the DMP and planned the creation of its datasets:</p>
# <ol>
#     <li>A dataset for the data collected</li>
#     <li>A dataset for the software generated to create/analyse the data</li>
# </ol>
# <p style="text-align:justify; font-size: 14.5px">We dediced to adopt the <a href="https://ec.europa.eu/research/participants/docs/h2020-funding-guide/cross-cutting-issues/open-access-data-management/data-management_en.htm">Horizon 2020 FAIR DMP template</a> and split the work on the two datasets: each of us has to work on a set of questions. Thus, today I answered the questions about</p>
# <ul>
#     <li>Allocation of resources (1st dataset)</li>
#     <li>Data security (1st dataset)</li>
#     <li>Ethical aspects (1st dataset)</li>
#     <li>Data summary (2nd dataset)</li>
# </ul>
#         <p style="text-align:justify; font-size: 14.5px">After completing the first draft of these answers, I still have some doubts about the features of the second dataset. In particular, it seems rather complex to properly identify the "<em>types of the described generated/collected data</em>". I will probably revise the answer to this question (<b>1.1.2</b>) after the next meeting with my team, as I am not enterily sure whether this dataset fits the classification provided by the <b>University of Virginia Library</b>: <a href="https://data.library.virginia.edu/data-management/plan/format-types/">here</a>.</p>
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: compilation of the DMP datasets' templates (<a href="https://argos.openaire.eu/splash/">Argos OpenAIRE</a>)</p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="11/04/2023" style="text-decoration:underline">11/04/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">During the last meeting, we decided how to design our project's <b>workflow</b>. The first step is about retrieving the set of Publications from ERIH-PLUS journals which are also included in the OpenCitation Meta dataset. We expect our results to be a DataFrame (Pandas) made up of four columns:</p>
# <ul>
#     <li>OpenCitation Publication Venue Internal ID</li>
#     <li>Issn (OpenCitation format, e.g.: <code>issn:1865-3804</code>*)</li>
#     <li>ERIH-PLUS Publication Venue Internal ID</li>
#     <li>Issn (ERIH-PLUS format, e.g.: <code>1865-3804</code>*)</li>
# </ul>
# <p style="text-align:justify; font-size: 12px">* Actually, columns 2 and 4 could be merged into a single one.</p>
# <p style="text-align:justify; font-size: 14.5px">How can we get these results given the first analysis on data organization (see <a href="#28/03/2023" style="font-style: italic;">28/03/2023</a> for further details)? We found out that OpenCitation Meta dataset can be queried from a <b>SPARQL</b> endpoint, available at this <a href="http://opencitations.net/meta/sparql">link</a>, thus I performed on it the following query:</p>
# <br>
# <div><code>PREFIX datacite: &lt;http://purl.org/spar/datacite/&gt;</code><br>
#     <code>PREFIX dcterms: &lt;http://purl.org/dc/terms/&gt;</code><br>
# <code>PREFIX literal: &lt;http://www.essepuntato.it/2010/06/literalreification/&gt;</code><br>
# <code>PREFIX prism: &lt;http://prismstandard.org/namespaces/basic/2.0/&gt;</code><br>
# <code>SELECT * {</code><br>
#  <code>?venue datacite:hasIdentifier ?internal_identifier .</code><br>
#  <code>?internal_identifier datacite:usesIdentifierScheme datacite:issn .</code><br>
#  <code>?internal_identifier literal:hasLiteralValue ?issn .</code><br>
# <code>}</code><br>
# </div><br>
# <p style="text-align:justify; font-size: 14.5px">The results have been dowloaded and stored in a file named <code>queryResults.csv</code>. At the same time, I downloaded the list of ISSNs included in the ERIH-PLUS index (<a href="https://kanalregister.hkdir.no/publiseringskanaler/erihplus/periodical/listApprovedISSN">here</a>) and stored them in a plain text file.</p>

# %%
import pandas as pd
df = pd.read_csv("C:/Users/sebas/Downloads/queryResults.csv")
df
# Out:
#                                             "venue"   \
# 0           "https://w3id.org/oc/meta/br/062501038"
# 1           "https://w3id.org/oc/meta/br/062501129"
# 2           "https://w3id.org/oc/meta/br/062501129"
# 3           "https://w3id.org/oc/meta/br/062501155"
# 4           "https://w3id.org/oc/meta/br/062501155"
# ...                                              ...
# 136023   "https://w3id.org/oc/meta/br/061803464677"
# 136024   "https://w3id.org/oc/meta/br/061803464695"
# 136025   "https://w3id.org/oc/meta/br/061803464699"
# 136026   "https://w3id.org/oc/meta/br/061803464707"
# 136027   "https://w3id.org/oc/meta/br/061803464728"
#
#                               "internal_identifier"         "issn"   \
# 0              "https://w3id.org/oc/meta/id/062501"    "0009-2797"
# 1              "https://w3id.org/oc/meta/id/062503"    "1521-3781"
# 2              "https://w3id.org/oc/meta/id/062504"    "0009-2851"
# 3              "https://w3id.org/oc/meta/id/062506"    "1522-2640"
# 4              "https://w3id.org/oc/meta/id/062507"    "0009-286X"
# ...                                              ...            ...
# 136023   "https://w3id.org/oc/meta/id/061803195739"    "2582-6271"
# 136024   "https://w3id.org/oc/meta/id/061803195740"    "2582-7421"
# 136025   "https://w3id.org/oc/meta/id/061803195741"    "2582-7804"
# 136026   "https://w3id.org/oc/meta/id/061803195742"    "2582-7960"
# 136027   "https://w3id.org/oc/meta/id/061803195743"    "2583-0074"
#
#         Unnamed: 3
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 136023         NaN
# 136024         NaN
# 136025         NaN
# 136026         NaN
# 136027         NaN
#
# [136028 rows x 4 columns]

# %%
with open('C:/Users/sebas/Downloads/issnLists.txt') as f:
    lines = f.readlines()
issn_str = lines[0]
issn_list = issn_str.split(",")
issn_list
# Out:
# ['0001-2343',
#  '0001-415X',
#  '0001-4273',
#  '0001-4788',
#  '0001-4966',
#  '0001-5210',
#  '0001-5229',
#  '0001-5830',
#  '0001-6241',
#  '0001-6438',
#  '0001-6446',
#  '0001-6829',
#  '0001-690X',
#  '0001-6918',
#  '0001-6993',
#  '0001-8244',
#  '0001-8392',
#  '0001-8791',
#  '0001-9720',
#  '0001-9909',
#  '0001-9933',
#  '0002-0184',
#  '0002-0206',
#  '0002-0591',
#  '0002-1482',
#  '0002-1490',
#  '0002-4805',
#  '0002-6980',
#  '0002-7189',
#  '0002-7294',
#  '0002-7316',
#  '0002-8312',
#  '0002-8762',
#  '0002-9114',
#  '0002-9300',
#  '0002-9319',
#  '0002-9432',
#  '0002-9475',
#  '0002-9483',
#  '0002-953X',
#  '0002-9556',
#  '0002-9831',
#  '0003-0139',
#  '0003-0279',
#  '0003-0481',
#  '0003-0554',
#  '0003-0651',
#  '0003-066X',
#  '0003-0678',
#  '0003-1186',
#  '0003-1224',
#  '0003-1283',
#  '0003-1615',
#  '0003-2468',
#  '0003-2565',
#  '0003-2573',
#  '0003-2638',
#  '0003-3472',
#  '0003-3790',
#  '0003-4436',
#  '0003-4487',
#  '0003-4800',
#  '0003-5033',
#  '0003-5459',
#  '0003-5491',
#  '0003-5521',
#  '0003-5548',
#  '0003-5815',
#  '0003-598X',
#  '0003-6390',
#  '0003-6870',
#  '0003-7982',
#  '0003-8008',
#  '0003-813X',
#  '0003-8504',
#  '0003-8628',
#  '0003-8970',
#  '0003-9101',
#  '0003-9292',
#  '0003-9519',
#  '0003-9756',
#  '0004-0002',
#  '0004-0088',
#  '0004-0177',
#  '0004-0207',
#  '0004-0428',
#  '0004-0452',
#  '0004-0665',
#  '0004-0975',
#  '0004-1327',
#  '0004-1610',
#  '0004-2927',
#  '0004-3079',
#  '0004-3249',
#  '0004-3702',
#  '0004-8402',
#  '0004-8992',
#  '0004-9441',
#  '0005-4283',
#  '0005-7894',
#  '0005-7916',
#  '0005-7959',
#  '0005-7967',
#  '0005-8076',
#  '0006-0887',
#  '0006-176X',
#  '0006-1913',
#  '0006-2294',
#  '0006-2456',
#  '0006-3223',
#  '0006-5714',
#  '0006-5722',
#  '0006-8977',
#  '0006-8993',
#  '0007-070X',
#  '0007-0874',
#  '0007-0882',
#  '0007-0904',
#  '0007-0955',
#  '0007-0998',
#  '0007-1005',
#  '0007-1013',
#  '0007-1080',
#  '0007-1102',
#  '0007-1234',
#  '0007-1269',
#  '0007-1315',
#  '0007-1773',
#  '0007-4403',
#  '0007-4640',
#  '0007-5140',
#  '0007-6201',
#  '0007-6503',
#  '0044-748X',
#  '0044-8699',
#  '0045-3102',
#  '0045-5091',
#  '0045-6713',
#  '0046-001X',
#  '0046-1520',
#  '0046-1628',
#  '0046-2616',
#  '0046-2772',
#  '0046-3663',
#  '0046-385X',
#  '0046-3892',
#  '0046-435X',
#  '0046-760X',
#  '0046-8444',
#  '0046-8541',
#  '0047-0767',
#  '0047-2212',
#  '0047-2336',
#  '0047-2352',
#  '0047-2395',
#  '0047-2441',
#  '0047-2484',
#  '0047-2506',
#  '0047-2662',
#  '0047-2727',
#  '0047-2778',
#  '0047-2786',
#  '0047-2794',
#  '0047-2875',
#  '0047-2891',
#  '0047-4045',
#  '0047-4800',
#  '0047-729X',
#  '0047-8105',
#  '0048-1009',
#  '0048-3486',
#  '0048-3893',
#  '0048-3915',
#  '0048-3931',
#  '0048-5675',
#  '0048-5772',
#  '0048-5829',
#  '0048-671X',
#  '0048-721X',
#  '0048-7333',
#  '0048-7651',
#  '0048-7694',
#  '0048-7988',
#  '0048-8046',
#  '0048-8593',
#  '0048-9115',
#  '0049-089X',
#  '0049-1241',
#  '0049-2361',
#  '0049-3155',
#  '0049-8637',
#  '0049-8653',
#  '0049-8661',
#  '0065-0900',
#  '0065-0986',
#  '0065-101X',
#  '0065-1044',
#  '0065-1141',
#  '0065-1583',
#  '0066-1392',
#  '0066-1546',
#  '0066-1554',
#  '0066-1619',
#  '0066-2062',
#  '0066-4677',
#  '0066-4774',
#  '0066-4871',
#  '0066-5061',
#  '0066-5215',
#  '0066-5924',
#  '0066-6041',
#  '0066-6505',
#  '0066-6637',
#  '0066-6742',
#  '0066-6785',
#  '0066-6874',
#  '0066-6890',
#  '0066-6939',
#  '0066-7358',
#  '0066-7374',
#  '0066-8176',
#  '0067-0081',
#  '0067-205X',
#  '0067-2378',
#  '0067-270X',
#  '0068-113X',
#  '0068-2454',
#  '0068-2462',
#  '0068-3175',
#  '0069-0058',
#  ...]

# %%
new_df = pd.DataFrame(columns=df.columns)
for idx, row in df.iterrows():
    if row[2].strip().split('"')[1] in issn_list:
        new_df = new_df.append(df.loc[idx], ignore_index=True)
new_df
# Out:
#                                            "venue"   \
# 0           "https://w3id.org/oc/meta/br/06501147"
# 1           "https://w3id.org/oc/meta/br/06501147"
# 2           "https://w3id.org/oc/meta/br/06501162"
# 3           "https://w3id.org/oc/meta/br/06501162"
# 4          "https://w3id.org/oc/meta/br/061201047"
# ...                                             ...
# 13877    "https://w3id.org/oc/meta/br/06103892867"
# 13878    "https://w3id.org/oc/meta/br/06803871825"
# 13879    "https://w3id.org/oc/meta/br/06903488133"
# 13880   "https://w3id.org/oc/meta/br/061103475568"
# 13881   "https://w3id.org/oc/meta/br/061103475568"
#
#                              "internal_identifier"         "issn"  Unnamed: 3
# 0              "https://w3id.org/oc/meta/id/06506"    "1557-7805"         NaN
# 1              "https://w3id.org/oc/meta/id/06507"    "0091-3367"         NaN
# 2              "https://w3id.org/oc/meta/id/06508"    "1541-3535"         NaN
# 3              "https://w3id.org/oc/meta/id/06509"    "0091-4150"         NaN
# 4             "https://w3id.org/oc/meta/id/061202"    "1471-6402"         NaN
# ...                                             ...            ...        ...
# 13877    "https://w3id.org/oc/meta/id/06103492509"    "2079-3634"         NaN
# 13878    "https://w3id.org/oc/meta/id/06803494574"    "2544-2031"         NaN
# 13879    "https://w3id.org/oc/meta/id/06903218004"    "2545-8329"         NaN
# 13880   "https://w3id.org/oc/meta/id/061103216283"    "2551-895X"         NaN
# 13881   "https://w3id.org/oc/meta/id/061103216284"    "2727-0831"         NaN
#
# [13882 rows x 4 columns]

# %% [markdown]
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: alternative ways to process META dataset, SPARQL query on META SPARQL endpoint</p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="15/04/2023" style="text-decoration:underline">15/04/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">The next task for the Open Science course is the production a <b>peer-review</b> on the <em>protocols.io</em> workflow created by the other Team. The first version this document is currently available at the following link: DOI <a href="dx.doi.org/10.17504/protocols.io.n92ldpeenl5b/v1">dx.doi.org/10.17504/protocols.io.n92ldpeenl5b/v1</a>. In order to fulfill this task, I've read some bibliography about peer-reviews. The major source I've followed during the production of my review is this article:</p>
# <ul>
#     <li>Stiller-Reeve, M. (2018). <em>How to write a thorough peer review</em>. Nature. <a href="https://doi.org/10.1038/d41586-018-06991-0">https://doi.org/10.1038/d41586-018-06991-0</a></li>
# </ul>
# <p style="text-align:justify; font-size: 14.5px">One of the main benefits of this article is that it suggests a <a href="https://www.scisnack.com/wp-content/uploads/2018/10/A-Peer-Review-Process-Guide.pdf">worksheet</a> that presents the main steps to follow when writing a review. The author suggests to read the article/document three times, focusing on different aspects with each reading. Here is a table containing some notes following the schema provided by this article.</p>
# <br>
# <div style="display:block">
# <table style="display:block; float:left; font-size: 14px; margin-bottom: 15px">
#     <tr style="background-color: #D6EEEE;">
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">#</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Question</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Notes</th>
#       </tr>
#       <tr style="background-color: #f7fbfd">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>1</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Is the article in line with the journal’s scope?</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Yes: it is perfectly in line with the course scope.</td>
#       </tr>
#       <tr style="background-color: #f7fbfd">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>2</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Does your expertise cover all aspects of the article? If not, describe which sections you can respond to and why?</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">I know Pandas and how to deal with .csv datasets. I'm familiar with META and ERIH-PLUS, while I don't know COCI.</td>
#       </tr>
#       <tr style="background-color: #f7fbfd">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>3</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>“Mirror” the article. Make a first draft describing the main aim of the article and why it’s innovative.</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">The article aims to identify and answer 3 questions included in the main research question. It seeks to facilitate access to and reuse of complex datasets by providing an additional source of information for new resources.</td>
#       </tr>
#       <tr style="background-color: #f7fbfd">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>4</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Is the article publishable in principle?</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Yes: though some steps should be further explained.</td>
#       </tr>
# </table>
#
# <table style="display:block; float:left; font-size: 14px; margin-bottom: 15px">
#     <tr style="background-color: #eef5ee;">
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">#</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Question</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Notes</th>
#       </tr>
#       <tr style="background-color: #fafcfa">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>5</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Do the Introduction and Abstract clearly identify the need and relevance for this research? </em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>Major Issue</b>: the abstract doesn't make very clear why we should need to work on these specific kinds of data. It might be unclear to readers not involved in this domain.</td>
#       </tr>
#       <tr style="background-color: #fafcfa">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>6</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Does the Methodology target the main question(s) appropriately?</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>Minor issue</b>: though it is implicitly derivable, readers may benefit from a thorough presentations of the data required to addess specific sub-questions.</td>
#       </tr>
#       <tr style="background-color: #fafcfa">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>7</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Are the Results clearly and logically presented, and are they justified by the data presented? Are the figures clear and fully described? </em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>Minor issues</b>: What's the final format of the results? Will the results be exported somewhere?</td>
#       </tr>
#       <tr style="background-color: #fafcfa">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>8</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Do the Conclusions justifiably respond to main questions the author(s) posed? Do the Conclusions go too far or not far enough based on the results?</em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">No issues</td>
#       </tr>
# </table>
#
# <table style="display:block; float:left; font-size: 14px; margin-bottom: 15px">
#     <tr style="background-color: #ffe1e7;">
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">#</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Question</th>
#         <th style="border: 1px solid #dddddd; text-align: left; padding: 8px;">Notes</th>
#       </tr>
#       <tr style="background-color: #fffafb">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>9</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>Is the manuscript’s story cohesive and tightly reasoned throughout? If not, where does it deviate from the central argument? </em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>Major Issue</b>: the last section is still empty. It should be either removed or populated with some new content.</td>
#       </tr>
#       <tr style="background-color: #fffafb">
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><b>10</b></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;"><em>How are the grammar and spelling in the manuscript? </em></td>
#         <td style="border: 1px solid #dddddd; text-align: left; padding: 8px;">No issue</td>
#       </tr>
# </table>
# </div>
# <p>UPDATE. The review is now available at the following link: <a href="https://doi.org/10.32388/LJL963">https://doi.org/10.32388/LJL963</a></p>
# <br>
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: preparing a peer-review about the Pika.py's protocol</p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="26/04/2023" style="text-decoration:underline">26/04/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">Today my team and I had a meeting to discuss how to improve and correct our documents on the basis of the other group's <b>reviews</b>. In particular, we focused mainly on the DMP revision, since we still have some doubts about the realization of our datasets. I would like to report some considerations annotated during the meeting (the suggestions by the other group are in italics):</p>
# <div style="display: block; width:90%; margin:2% 4%"><h4>About the DMP:</h4>
#     <ul style="text-align:justify; font-size: 14.5px">
#         <li>Section 3.1.1.3: We probably need to change the answer (No → Yes) to this question and check whether we want to update the specified standards (NOTE: the later answers we provided suggest the need to present metadata, so it would be more consistent to use controlled vocabularies).</li>
#         <li>Sections 3.1.1.7, 3.1.1.8: <em>specify the idea you had about the use of naming conventions for data</em>. One possible way to tackle this problem is to use the naming conventions provided by a controlled vocabulary (we should decide which one).</li>
#         <li>Section 3.1.1.9: Introduce version numbers for data. We should remove the “if necessary”expression and explain how the version number will be updated (e.g: major vs minor changes? For instance, 1 → 2 or 1 → 1.1 ).</li>
#         <li>Section 1.1.3 (software dataset): <em>you answered to “What are the formats of the described generated/collected data?” with “Software”</em> → we should make clear what’s the content of this dataset (either python script or a set of data, for instance in csv format).
#         </li>
#         <li>Section 1.1.4: we have to explain whether we have some authorisations to manipulate the original data and work on them. Therefore, we must look for specific authorisations/licenses for each source.</li>
#         <li>Section 3.1.2.5: <em>The back-up procedure described fit for purpose and multiple media are considered for it, but there is no considered measures to check the usability of the back-up copies.</em> Is it sufficient to periodically check that our back-up is accessible and usable? We should check that the data has not been altered or corrupted (Ali suggested "checksums" as a possible means of doing this).</li>
#     </ul>
#     <h4>About the Protocol:</h4>
#     <ul style="text-align:justify; font-size: 14.5px">
#         <li>We need to correct the title of the Protocol and the OpenCitations Meta Dump name. Moreover, we have to specify whether we want to publish our data in a repository (YES) and remove the SPARQL endpoint option (Step 1.1). Then, we should the change the value about the open-acess status of journals which are not included in the DOAJ directory: from “FALSE” to “UNKNOWN”.</li>
#         <li>Section 2.1: provide more details of the script (enrich this section).</li>
#         <li>Section 2.3: <em>In 2.3 you only assess the case in which missing information can be retrieved by looking at DOAJ. What happens if these metadata cannot be found there?</em>. We still need to tackle this part.</li>
#         <li><em>I would suggest to provide a comprehensive visualisation to allow a clearer overall view of the situation.</em> We should choose how to visualize our results. For instance, we could consider one of the following options: website, slides, jupyternotebook.</li>
#     </ul>
# </div>
# <div style="display:block; background-color: #D4F1F4; border-radius: 3px; border: 1pt solid #89CFF0; padding: 5px 10px; width: 90%; margin-left:5%; margin-top: 10px"><p><b>ON THIS DATE</b>: an analysis of the peer-reviews of our Protocol and DMP</p></div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="02/05/2023" style="text-decoration:underline">02/05/2023</h3>
# <p style="text-align:justify; font-size: 14.5px"><b><em>Getting ready for the next meeting...</em></b> We need to prepare an article to explain how we intend to address the issues raised by the peer-reviews we received. Let's start with an analysis of the issues related to our Protocol:</p>
# <div style="display: block; width:90%; margin:2% 4%"><h4>About Section 2.1 (<em>Disciplines</em>):</h4>
#     <p style="text-align:justify; font-size: 14.5px">Both ERIH-PLUS and DOAJ provide a classification of disciplines. In particular, the latter follows the <a href="https://www.loc.gov/catdir/cpso/lcco/">Library of Congress Classification Outline</a>, while the former introduces two standardized classifications (i.e.: ERIH PLUS Disciplines; OECD Classifications). We chose ERIH PLUS as a source to analyze "which disciplines have the most publications?": however, we should better explain how we intend to exploit it. This is how we can extract this data:</p>
#     </div>

# %%
import pandas as pd

file_path = "C:/Users/sebas/Downloads/2023-04-30 ERIH PLUS approved journals and series.csv" 
erih_df = pd.read_csv(file_path, delimiter=";") # open erih_plus dataset
erih_df_disciplines = erih_df.iloc[0:10,6:8]  # for simplicity, let's focus on the first 10 elements of the dataset
erih_df_disciplines
# Out:
#                                ERIH PLUS Disciplines  \
# 0  Interdisciplinary research in the Social Scien...
# 1  Art and Art History, Cultural Studies, Human G...
# 2  Gender Studies, Cultural Studies, Literature, ...
# 3  Interdisciplinary research in the Humanities, ...
# 4  Interdisciplinary research in the Social Sciences
# 5                     Science and Technology Studies
# 6                                         Literature
# 7  Art and Art History, Classical Studies, Cultur...
# 8  History, Cultural Studies, Interdisciplinary r...
# 9  History, Interdisciplinary research in the Hum...
#
#                                 OECD Classifications
# 0        Educational Sciences; Other Social Sciences
# 1  Arts (Arts, History of Arts, Performing Arts, ...
# 2  Languages and Literature; Other Humanities; So...
# 3            Other Humanities; Other Social Sciences
# 4                              Other Social Sciences
# 5                              Other Social Sciences
# 6                           Languages and Literature
# 7  Arts (Arts, History of Arts, Performing Arts, ...
# 8  History and Archaeology; Languages and Literat...
# 9          History and Archaeology; Other Humanities

# %% [markdown]
# <div style="display: block; width:90%; margin:2% 4%">
#     <p style="text-align:justify; font-size: 14.5px">However, <b>multiple disciplines</b> might be included in the same journal: can each individual publication be associated with its specific discipline? A set of disciplines could be associated with the number of articles included in a journal through an intersection with data provided by OC Meta, but does it really work? We should decide which kind of reference we would like to epxploit for this task.</p>
#     <p style="text-align:justify; font-size: 14.5px"><b>ERIH PLUS disciplines</b>: Anthropology, Archaeology, Art and Art History, Business and Management, Classical Studies, Cultural Studies, Demography, Economics, Environmental Studies, Film and Theatre Studies, Gender Studies, History, History &amp; Philosophy of Science, Human Geography and Urban Studies, Interdisciplinary research in the Humanities, Interdisciplinary research in the Social Sciences, Law, Library and Information Science, Linguistics, Literature, Media Studies and Communication, Musicology, Pedagogical &amp; Educational Research, Philosophy, Political Sciences and International Relations, Psychology, Religious Studies and Theology, Science and Technology Studies, Social Statistics and Informatics, Sociology</p>
#     <p style="text-align:justify; font-size: 14.5px"><b>OECD disciplines</b>:

# %%
OECD_set = set()
OECD_disciplines = erih_df.iloc[0:,7:8]
for idx, row in OECD_disciplines.iterrows():
    inner_list = row["OECD Classifications"].split("; ")
    for el in inner_list:
        OECD_set.add(el)
OECD_set
# Out:
# {'Arts (Arts, History of Arts, Performing Arts, Music)',
#  'Economics and Business',
#  'Educational Sciences',
#  'History and Archaeology',
#  'Languages and Literature',
#  'Law',
#  'Media and Communications',
#  'Other Humanities',
#  'Other Social Sciences',
#  'Philosophy, Ethics and Religion',
#  'Political Science',
#  'Psychology',
#  'Social and Economic Geography',
#  'Sociology'}

# %% [markdown]
# <p style="text-align:justify; font-size: 14.5px">How to address the issue: we need to decide whether it is right to classify disciplines at the journal (not article) level. Then, we need to choose which classification best suits our purposes. We could also propose two classifications: a more specific one based on ERIH PLUS disciplines and a broader one based on OECD. Once we choose the classification, we need to decide which calculation we want to perform. For example, we could directly compare the counts of all disciplines or we could compare the frequency of each discipline (i.e.: <em>freq = discipline_count / journal_numbers</em>).</p>

# %% [markdown]
# <div style="display: block; width:90%; margin:2% 4%"><h4>About Section 2.3 (<em>Countries</em>):</h4>
#     <p style="text-align:justify; font-size: 14.5px">"What are countries providing the largest number of publications  and journals?". Once again, we can answer this question by taking into account the information provided by ERIH PLUS and DOAJ.</p>

# %%
count = 0
print_issn, online_issn = [], [] #store issn that are not associated with a country of publication
for idx, row in erih_df.iterrows():
    if type(row["Country of Publication"]) != type(str()):
        count +=1
        if type(row["Print ISSN"]) == type(str()):
            print_issn.append(row["Print ISSN"])
        if type(row["Online ISSN"]) == type(str()):     
            online_issn.append(row["Online ISSN"]) 
count
# Out:
# 121

# %% [markdown]
# <div style="display: block; width:90%; margin:2% 4%">
#     <p style="text-align:justify; font-size: 14.5px">In ERIH PLUS, 121 journals are not associated with their country of publication. Let's see if this information can be found in DOAJ:</p>

# %%
file_path_doaj = "C:/Users/sebas/Downloads/journalcsv__doaj_20230502_1235_utf8.csv" 
doaj_df = pd.read_csv(file_path_doaj, encoding="UTF-8")
doaj_df.head()
# Out:
#                               Journal title  \
# 0  Anais da Academia Brasileira de Ciências
# 1                                      ACME
# 2                  Acta Biochimica Polonica
# 3                Acta Dermato-Venereologica
# 4                 Acta Médica Costarricense
#
#                                          Journal URL  \
# 0  http://www.scielo.br/scielo.php?script=sci_ser...
# 1             http://riviste.unimi.it/index.php/ACME
# 2           https://ojs.ptbioch.edu.pl/index.php/abp
# 3            https://medicaljournalssweden.se/actadv
# 4  http://actamedica.medicos.cr/index.php/Acta_Me...
#
#                                          URL in DOAJ  \
# 0  https://doaj.org/toc/ed09859a464f4461b1af34279...
# 1  https://doaj.org/toc/b1ca04ba56194f29a362b3eef...
# 2  https://doaj.org/toc/eea321d7f4c34a59be8fd1203...
# 3  https://doaj.org/toc/ffde9666ab1d46f1a8c688ce6...
# 4  https://doaj.org/toc/a5919aee5ad2413a89cf32df0...
#
#    When did the journal start to publish all content using an open license?  \
# 0                                             2000.0
# 1                                             2014.0
# 2                                             2000.0
# 3                                             2017.0
# 4                                             2019.0
#
#                              Alternative title Journal ISSN (print version)  \
# 0  Annals of the Brazilian Academy of Sciences                    0001-3765
# 1                                          NaN                    0001-494X
# 2                                          NaN                    0001-527X
# 3                                          NaN                    0001-5555
# 4                                          NaN                    0001-6012
#
#   Journal EISSN (online version)  \
# 0                      1678-2690
# 1                      2282-0035
# 2                      1734-154X
# 3                      1651-2057
# 4                      2215-5856
#
#                                             Keywords  \
# 0  biological sciences, exact and earth sciences,...
# 1  italian literature, classic literature, lingui...
# 2  molecular biology, biophysics, bioinformatics,...
# 3  sexually transmitted infections, psoriasis, ps...
# 4  medicine, public health, medical sciences, health
#
#   Languages in which the journal accepts manuscripts  \
# 0                                            English
# 1                                            Italian
# 2                                            English
# 3                                            English
# 4                                   Spanish, English
#
#                                       Publisher  ...  \
# 0               Academia Brasileira de Ciências  ...
# 1              Università degli Studi di Milano  ...
# 2                    Polish Biochemical Society  ...
# 3                       Medical Journals Sweden  ...
# 4  Colegio de Médicos y Cirujanos de Costa Rica  ...
#
#              URL for journal's Open Access statement Continues Continued By  \
# 0    http://www.scielo.br/revistas/aabc/isubscrp.htm       NaN          NaN
# 1  http://riviste.unimi.it/index.php/ACME/about/e...       NaN          NaN
# 2     https://ojs.ptbioch.edu.pl/index.php/abp/about       NaN          NaN
# 3   https://medicaljournalssweden.se/actadv/oapolicy       NaN          NaN
# 4  http://actamedica.medicos.cr/index.php/Acta_Me...       NaN          NaN
#
#              LCC Codes                                           Subjects  \
# 0                    Q                                            Science
# 1                    A                                      General Works
# 2  QD415-436|QH426-470  Science: Chemistry: Organic chemistry: Biochem...
# 3              RL1-803                              Medicine: Dermatology
# 4                    R                                           Medicine
#
#   DOAJ Seal         Added on Date     Last updated Date  \
# 0        No  2004-04-23T21:31:00Z  2017-01-04T14:19:54Z
# 1        No  2014-12-22T19:55:58Z  2022-08-10T19:13:04Z
# 2        No  2022-05-23T10:09:09Z  2022-05-23T10:09:09Z
# 3        No  2011-11-10T12:31:05Z  2023-01-19T09:14:05Z
# 4        No  2020-12-22T11:08:24Z  2022-07-29T11:54:21Z
#
#   Number of Article Records Most Recent Article Added
# 0                      3935      2023-05-02T07:34:13Z
# 1                       224      2023-03-16T15:14:11Z
# 2                         0                       NaN
# 3                      1604      2023-04-27T08:50:07Z
# 4                      1207      2015-12-08T15:06:43Z
#
# [5 rows x 54 columns]

# %%
new_doaj = doaj_df.iloc[1:, [5, 6, 10]]
new_doaj
# Out:
#       Journal ISSN (print version) Journal EISSN (online version)  \
# 1                        0001-494X                      2282-0035
# 2                        0001-527X                      1734-154X
# 3                        0001-5555                      1651-2057
# 4                        0001-6012                      2215-5856
# 5                        0001-625X                      2353-074X
# ...                            ...                            ...
# 19266                    2967-0837                      2968-0115
# 19267                    2971-5121                            NaN
# 19268                          NaN                      2974-668X
# 19269                          NaN                      2975-3848
# 19270                    8755-6839                      2168-6009
#
#       Country of publisher
# 1                    Italy
# 2                   Poland
# 3                   Sweden
# 4               Costa Rica
# 5                   Poland
# ...                    ...
# 19266               France
# 19267              Nigeria
# 19268                Italy
# 19269              Croatia
# 19270        United States
#
# [19270 rows x 3 columns]

# %%
count_2 = 0
missing_issn = []
for idx, row in new_doaj.iterrows():
    if row["Journal ISSN (print version)"] in print_issn and type(row["Country of publisher"]) == type(str()):
        #print(row["Journal ISSN (print version)"], row["Country of publisher"])
        count_2 +=1
    elif row["Journal ISSN (print version)"] in print_issn and type(row["Country of publisher"]) != type(str()):
        missing_issn.append(row["Journal ISSN (print version)"])
    if row["Journal EISSN (online version)"] in online_issn and type(row["Country of publisher"]) == type(str()):
        #print(row["Journal EISSN (online version)"], row["Country of publisher"])
        count_2 +=1
    elif row["Journal EISSN (online version)"] in online_issn and type(row["Country of publisher"]) != type(str()):
        missing_issn.append(row["Journal EISSN (online version)"])
        
print(missing_issn)
count_2
# Out:
# []
# 89

# %% [markdown]
# <div style="display: block; width:90%; margin:2% 4%">
#     <p style="text-align:justify; font-size: 14.5px">Some of the missing Countries of Publication can be found in DOAJ, however, there are still some missing countries to identify. Unfortunately, the missing issn can't be found in DOAJ.</p>
# </div>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="08/05/2023" style="text-decoration:underline">08/05/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">Today afternoon we had a new meeting: we continued our revision process of the reviews by the our group and almost finished to write the rebuttal letters. We are currently trying to design e write our program on the basis of the protocol. In particular, Ali has already provided a possible structure for our code, but it's time to find the most efficient way to parse our dataset.</p>
# <p style="text-align:justify; font-size: 14.5px">The first dataset we have to analyze is the OpenCitations Meta dump, which contains more than 22000 .csv files. We have decided to process those files in parallel, but we still need to find the most effective way to get faster and more accurate results. In particular, I'm observing that the <code>pandas.DataFrame.merge</code> is too slow, so we cannot use it in order to associate OpenCitations Meta entities with the correspondent ERIH PLUS journals. My idea is to retrieve a list containing all the issn identifiers recorded in ERIH PLUS, iterate the items of the column <code>"issn"</code> of each OCMeta DataFrame (<code>df['issn'].items()</code>) and save the indexes that we want to keep. I've already tried to implement this solution and the code seems to be much faster: from 9.30 hours to 27 minutes (expected time)</p>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="09/05/2023" style="text-decoration:underline">09/05/2023</h3>
# <p style="text-align:justify; font-size: 14.5px">Today morning we had a new meeting: Maddalena is currently finishing to write the last rebuttal letter, while the protocol is ready and its new version has been released. Now we are ready to actively work on our program. My suggestion is to provide the end user with a mechanism to easily run the code from terminal and with the possibility of adding some parameters. For instance, it might be useful to allow the specification of the path to datasets' folders. E.g.: <code>python main.py --path_to_OCMeta_dump =  ...</code> .</p>
# <p style="text-align:justify; font-size: 14.5px">From now on, me and my team will work on different tasks: the protocol represents our guidelines, it tells us what input we expect to get and what results we want to return for each of the tasks. For instance, I'm currently working on adding a new column to the OpenCitations Meta Coverage Dataframe: it will cointains a specification of the Open Access status for each of the journals. Thus, I am going to work on combining the DataFrame with some information included in the DOAJ dataset.</p>
# <hr style="border: 1pt solid #89CFF0">

# %% [markdown]
# <h3 id="18/05/2023" style="text-decoration:underline">18/05/2023</h3>
# <p style="text-align:justify; font-size: 14.5px"><b><em>Some visualizations experiments</em></b>: today I would like to test some visualizations for our output dataframes.</p>
# <ul>
#     <li><b>1. Disciplines by Publications</b>:<br> Which are the most frequent disciplines according to our data?</li>

# %%
import matplotlib.pyplot as plt
import pandas as pd

unordered_discplines = pd.read_csv("../../../2022-2023-playarists-code/oop-approach/remix/disciplines.csv")
disciplines = unordered_discplines.sort_values(by='Publication_count', ascending=True)

colors = ['steelblue', 'skyblue', 'lightskyblue', 'deepskyblue', 'dodgerblue', 'cornflowerblue',
          'mediumblue', 'royalblue', 'mediumslateblue', 'slateblue', 'blueviolet', 'darkviolet',
          'mediumorchid', 'indigo', 'purple', 'darkmagenta', 'palegreen', 'limegreen', 'forestgreen',
          'darkgreen', 'gold', 'goldenrod', 'darkorange', 'chocolate', 'sienna', 'saddlebrown',
          'tomato', 'orangered', 'firebrick', 'crimson', 'maroon']

plt.barh(disciplines['Discipline'], disciplines['Publication_count'], color=colors, height=0.9)
plt.xlabel('Publications')
plt.ylabel('Discipline')
plt.title('Disciplines by Publication')
plt.subplots_adjust(top=1.1)
plt.grid(axis="x", linewidth=0.2)

plt.show()

# %% [markdown]
# <ul>
#     <li><b>2. Countries by Publications (Top 30)</b>:<br> Which are the countries with the highest number of publications? The barplot is based on a logarithmic scale to better visualize results (huge gap between US and other results)</li>

# %%
import numpy as np

unordered_countries = pd.read_csv("../../../2022-2023-playarists-code/oop-approach/remix/countries.csv")
all_countries = unordered_countries.sort_values(by='Publication_count', ascending=True)
countries = all_countries.iloc[-30:]

colors = ['steelblue', 'skyblue', 'lightskyblue', 'deepskyblue', 'dodgerblue', 'cornflowerblue',
          'mediumblue', 'royalblue', 'mediumslateblue', 'slateblue', 'blueviolet', 'darkviolet',
          'mediumorchid', 'indigo', 'purple', 'darkmagenta', 'palegreen', 'limegreen', 'forestgreen',
          'darkgreen', 'gold', 'goldenrod', 'darkorange', 'chocolate', 'sienna', 'saddlebrown',
          'tomato', 'orangered', 'firebrick', 'crimson', 'maroon']

plt.barh(countries['Country'], countries['Publication_count'], color=colors, height=0.9)
plt.xlabel('Publication Count')
plt.xscale('log')
plt.ylabel('Country')
plt.title('Countries by Publications (Top 30)')
plt.subplots_adjust(top=1.1, right=1.2)
plt.grid(axis="x", linewidth=0.2)
x_values = np.array([100, 1000, 10000, 100000, 1000000]) 
plt.xticks(x_values, x_values)


plt.show()

# %% [markdown]
# <hr style="border: 1pt solid #89CFF0">
